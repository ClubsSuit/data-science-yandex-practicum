# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px; ">
# <b> Комментарий ревьюера</b>
#
# Привет! Меня зовут Света, я буду проверять твой проект. Если не против, давай общаться на «ты». Если тебе такой стиль общения не нравится, напиши об этом, будем на «вы».
#
# Сразу хочу обратить внимание на цветовую разметку:
#
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Зеленым с пометкой ✔️ отмечены отличные решения и идеи, которые можно и нужно использовать в будущем.
# </div>
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Желтым с пометкой ⚠️ отмечено то, что можно или нужно оптимизировать, в зависимости от контекста.</div>
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Красным с пометкой ❌ обозначены пропущенные пункты задания и ошибки, которые обязательно надо будет исправить, чтобы результаты были верные.</div>
#
# **Ответы на мои комментарии или доработки по моим рекомендациям попрошу выделить каким-нибудь цветом, кроме трех перечисленных.**
# Также я попрошу тебя **не менять и не передвигать мои комментарии**, чтобы при последующей проверке мне было проще ориентироваться.
#
# Кроме того, комментарии у меня обозначены как заголовки. Это сбивает содержание, но при последующей проверке я могу снять с них заголовок, если тебе так будет удобнее. При этом они удобны, поскольку ты сразу можешь перейти к ним.
#
# <hr>
#
# <font color= 'dodgerblue'>**По проекту:**</font> работа сделана очень хорошо, все оформлено аккуратно и понятно. Структура работы у тебя грамотная, код легко читается. У меня остались некоторые вопросы, я все обозначила в комментариях. Там же я оставила рекомендации по улучшению проекта. Буду ждать работу на повторное ревью.
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Комментарий ревьюера 2</b>
#
# Спасибо за корректировки. Я оставила новые комментарии с цифрой 2. Надеюсь, тема была интересной. Проект я могу принять, поскольку вопросов больше нет. Желаю успехов на следующих спринтах! 😊
#
#
#
# </div>

# %% [markdown]
# # Определение возраста покупателей

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера  ❌</b>
#
# Вводный параграф это неотъемлемая часть любого проекта, отчета, презентации или статьи. Будет очень здорово, если ты добавишь постановку задачи: краткое ее описание и описание данных. Это поможет не только тебе лучше ориентироваться в проекте спустя некоторое время, но и потенциальному работодателю, который будет просматривать твое портфолио.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Это полезная привычка. Потом тебе будет проще вспоминать, что это за проект. К примеру, у меня на компьютере около сотни (если не больше) различных тетрадок с задачами, если не больше. От древних тетрадей с простыми задачами до важных проектов. Тут без комментариев ни за что не вспомнишь, о чем там речь шла и что вообще происходит в проекте :)
#
# </div>

# %% [markdown]
# Сетевой супермаркет «Хлеб-Соль» внедряет систему компьютерного зрения для обработки фотографий покупателей. Фотофиксация в прикассовой зоне поможет определять возраст клиентов, чтобы:
# * Анализировать покупки и предлагать товары, которые могут заинтересовать покупателей этой возрастной группы;
# * Контролировать добросовестность кассиров при продаже алкоголя.
#
# Для этого обучим модель на датасете, который содержит набор фотографий лиц людей и их возраст. Оценивать модель будем по метрике MAE. Достаточным результатом будет MAE меньше 8 лет.

# %% [markdown]
# ## Исследовательский анализ данных

# %%
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
labels = pd.read_csv('/datasets/faces/labels.csv')
datagen = ImageDataGenerator(rescale=1./255)
gen_flow = datagen.flow_from_dataframe(
        dataframe=labels,
        directory='/datasets/faces/final_files/',
        x_col='file_name',
        y_col='real_age',
        target_size=(224, 224),
        batch_size=32,
        class_mode='raw',
        seed=12345)
# Out:
# Found 7591 validated image filenames.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера  ⚠️</b>
#
# - Импорты лучше выносить в отдельную ячейку.
#
#
#
# - Я бы рекомендовала использовать более нейтральные имена. Приставки вроде **train** или **val** лучше не использовать. Проекты с нейросетями обычно довольно объемные, поэтому перепутать названия этого датафрейма и тренировочной подвыборки может быть легко. Да, ты определяешь выборки внутри класса или функции, но иногда мы сначала пишем каркас кода, а уже потом оборачиваем его в класс. По этой причине лучше себя обезопасить и сразу назвать датафрейм как-то иначе.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# 👍
# </div>

# %%
labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7591 entries, 0 to 7590
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   file_name  7591 non-null   object
#  1   real_age   7591 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 118.7+ KB

# %%
labels["real_age"].hist(bins=50)
plt.title('Распределение возраста людей в датасете')
plt.xlabel('Возраст')
plt.ylabel('Количество фотографий')
plt.show()

# %%
labels.boxplot("real_age")
plt.title('Распределение возраста людей в датасете')
plt.ylabel('Возраст')
plt.show()

# %% [markdown]
# По графику видно что большинство фотографий людей от 10 до 40 лет, с максимумом в 30 годах.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера  ❌</b>
#
# Графики желательно не только сразу комментировать, но и подписывать (оси + заголовок). Оформлять подписи следует на языке заказчика. Делать это можно с помощью указанных ниже команд, где plt это сокращение matplotlib.pyplot. Подправь, пожалуйста.
#
# </div>
#
# ```python
#
# plt.title('Заголовок')
# plt.xlabel('Подпись')
# plt.ylabel('Подпись')
# ```
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера  ⚠️</b>
#
# Используй `plt.show()` или точку с запятой в конце кода, чтобы убрать подпись над графиком.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Замечательно :) Графики это весьма сильный инструмент в нашей работе, поэтому они важны. Ну а т.к. довольно часто приходится их презентовать, подписи просто необходимы.
# </div>

# %%
x_batch, y_batch = next(gen_flow)
fig, axes = plt.subplots(nrows=4, ncols=8, figsize=(12,6))
for i, ax in enumerate(axes.flat):
    ax.imshow(x_batch[i])
    ax.axis('off')
plt.show()

# %%
len(labels["real_age"].unique())
# Out:
# 97

# %% [markdown]
# Был загружен датасет фотографий лиц людей, фотографии различны как ч/б так и цветные, также есть фото с аугментациями. Все в сете 97 различных возрастов.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера  ❌</b>
#
# Как распределен возраст?
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Увидела выше вывод, отлично. </div>

# %% [markdown]
# ## Обучение модели

# %% [markdown]
# Перенесите сюда код обучения модели и её результат вывода на экран.
#
#
# (Код в этом разделе запускается в отдельном GPU-тренажёре, поэтому оформлен не как ячейка с кодом, а как код в текстовой ячейке)

# %% [markdown]
# ```python
#
# from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.applications.resnet import ResNet50
# import pandas as pd
#
# optimizer = Adam(lr=0.0005)
#
#
# def load_train(path):
#     datagen = ImageDataGenerator(validation_split=0.25, rescale=1./255)
#     train_datagen = datagen.flow_from_dataframe(
#         pd.read_csv(path + '/labels.csv'),
#         directory = path + '/final_files',
#         x_col = 'file_name',
#         y_col = 'real_age',
#         target_size=(224, 224),
#         batch_size=32,
#         class_mode='raw',
#         subset='training',
#         seed=12345)
#     return train_datagen
#
# def load_test(path):
#     datagen = ImageDataGenerator(validation_split=0.25, rescale=1./255)
#     test_datagen = datagen.flow_from_dataframe(
#         pd.read_csv(path + '/labels.csv'),
#         directory = path + '/final_files',
#         x_col = 'file_name',
#         y_col = 'real_age',
#         target_size=(224, 224),
#         batch_size=32,
#         class_mode='raw',
#         subset='validation',
#         seed=12345)
#     return test_datagen
#
# def create_model(input_shape):
#     backbone = ResNet50(input_shape=input_shape,
#                         weights='imagenet',
#                         include_top=False)
#     model = Sequential()
#     model.add(backbone)
#     model.add(GlobalAveragePooling2D())
#     model.add(Dense(64, input_dim=4, activation='relu')),
#     model.add(Dense(1))
#     model.compile(optimizer=optimizer, loss='mse',
#                   metrics=['mae'])
#
#     return model
#
#
# def train_model(model, train_data, test_data, batch_size=None, epochs=5,
#                 steps_per_epoch=None, validation_steps=None):
#     train_datagen = train_data
#     model.fit(train_datagen,
#               validation_data=test_data,
#               batch_size=batch_size, epochs=epochs,
#               steps_per_epoch=steps_per_epoch,
#               validation_steps=validation_steps,
#               verbose=2, shuffle=True)
#
#     return model
#
# ```

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Все верно.
# </div>

# %% [markdown]
# ```
# Train for 178 steps, validate for 60 steps
# Epoch 1/5
# 178/178 - 53s - loss: 194.8185 - mae: 10.4785 - val_loss: 440.2302 - val_mae: 15.9062
# Epoch 2/5
# 178/178 - 42s - loss: 104.0856 - mae: 7.7290 - val_loss: 387.4866 - val_mae: 14.7334
# Epoch 3/5
# 178/178 - 42s - loss: 66.0794 - mae: 6.2321 - val_loss: 339.4608 - val_mae: 13.6607
# Epoch 4/5
# 178/178 - 43s - loss: 41.4869 - mae: 4.9916 - val_loss: 305.9459 - val_mae: 12.9000
# Epoch 5/5
# 178/178 - 42s - loss: 26.0256 - mae: 3.9302 - val_loss: 89.9261 - val_mae: 7.1892
# 60/60 - 10s - loss: 89.9261 - mae: 7.1892
# Test MAE: 7.1892
# ```

# %% [markdown]
# ## Анализ обученной модели

# %% [markdown]
# Для построения модели использовалась сеть ResNet50 c финальными слоями пулинга, слоя с 64 нейронами и финального слоя с одним нейроном. Обученная модель продемонстрировала не плохие результаты оценки возраста людей по фотографии. Тестовое MAE составило 7.2 года. Для оценки совершеннолетия покупателя данная точность не достаточна, но для категоризации по возрастной группе может подойти.
# Для увеличения погрешности можно:
# * подобрать количество полносвязных слоев и нейронов в них
# * увеличить количество эпох процесса обучения
# * исполльзовать аугментации фотографий
# * увеличить объём датасета фотографий

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Здорово, что не забываешь про общий вывод.
#
# </div>
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера  ⚠️</b>
#
# Конечно, результаты удовлетворяют условиям ТЗ. Однако если смотреть на них глазами кассира, погрешность довольно большая. Как думаешь, какими способами можно улучшить качество модели?
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера  ❌</b>
#
# Расширь вывод, пожалуйста. Какая архитектура использовалась, что можно улучшить и т.д. Сейчас общий вывод кажется меньше промежуточного. </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Верно мыслишь. Использование агументаций (кстати, вот интересная библиотека: [albumentations](https://github.com/albumentations-team/albumentations)) и увеличение числа слоев может улусшить качество. Также можно рассмотреть использование методов борьбы с переобучением (тот же dropout, к примеру). Что касается оптимизатора и шага градиента, то тут все хорошо.  Adam довольно универсален, хотя и уступает в некоторых вещах SGD и AdamW. Он хорош тем, что довольно быстро ищет минимум. Но если есть время на эксперименты и если это необходимо, то действительно можно попробовать разные методы оптимизации. При желании можно попробовать использовать [LearningRateScheduler](https://keras.io/api/callbacks/learning_rate_scheduler/), который меняет шаг в зависимости от стадии обучения. Правда, с малым числом эпох в этом не так много смысла :)
#
#
# Неплохой идеей будет использование других предобученных моделей.
# </div>

# %% [markdown]
# ## Чек-лист

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Исследовательский анализ данных выполнен
# - [x]  Результаты исследовательского анализа данных перенесены в финальную тетрадь
# - [x]  MAE модели не больше 8
# - [x]  Код обучения модели скопирован в финальную тетрадь
# - [x]  Результат вывода модели на экран перенесён в финальную тетрадь
# - [x]  По итогам обучения модели сделаны выводы
