# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Привет, меня зовут Александр Куимов. Я буду ревьюером твоего проекта. Ты можешь обращаться ко мне на "ты"😏 Надеюсь, тебя также не смутит, если я буду обращаться к тебе на "ты", но если это неудобно, обязательно скажи об этом!
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь реагировать на мои комментарии своими по шаблону, показанному чуть ниже. Это нужно, чтобы не создавалась путаница😉
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
#
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> В такой цветовой ячейке я прошу тебя оставлять свои комментарии. Если исправляешь проект на второй итерации и выше, не забывай пожалуйста указывать номер итерации, например, "Комментарий студента v.2".
# </div>
#
# <br/>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе датасаентистом. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Корректировка-типов-данных" data-toc-modified-id="Корректировка-типов-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Корректировка типов данных</a></span></li><li><span><a href="#Заполнение-пропусков" data-toc-modified-id="Заполнение-пропусков-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Заполнение пропусков</a></span></li><li><span><a href="#Проверка-правильности-расчета-коэффициента-восстановления-recovery" data-toc-modified-id="Проверка-правильности-расчета-коэффициента-восстановления-recovery-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Проверка правильности расчета коэффициента восстановления <code>recovery</code></a></span></li><li><span><a href="#Анализ-признаков-в-тренировочной-и-тестовой-таблицах" data-toc-modified-id="Анализ-признаков-в-тренировочной-и-тестовой-таблицах-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Анализ признаков в тренировочной и тестовой таблицах</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Расчет-конццентрации-металлов-на-разных-этапах" data-toc-modified-id="Расчет-конццентрации-металлов-на-разных-этапах-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Расчет конццентрации металлов на разных этапах</a></span></li><li><span><a href="#Анализ-отличий-в-размерах-гранул-руды-для-тренировочной-и-тестовой-выборках" data-toc-modified-id="Анализ-отличий-в-размерах-гранул-руды-для-тренировочной-и-тестовой-выборках-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Анализ отличий в размерах гранул руды для тренировочной и тестовой выборках</a></span></li><li><span><a href="#Расчёт-финальных-концентраций" data-toc-modified-id="Расчёт-финальных-концентраций-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Расчёт финальных концентраций</a></span></li><li><span><a href="#Удаление-выбросов-в-данных" data-toc-modified-id="Удаление-выбросов-в-данных-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Удаление выбросов в данных</a></span></li><li><span><a href="#Изучиние-корреляции-данных-по-каждому-этапу" data-toc-modified-id="Изучиние-корреляции-данных-по-каждому-этапу-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Изучиние корреляции данных по каждому этапу</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Функция-для-расчета-финальной-метрики-sMAPE" data-toc-modified-id="Функция-для-расчета-финальной-метрики-sMAPE-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Функция для расчета финальной метрики sMAPE</a></span></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Обучение моделей</a></span></li><li><span><a href="#Проверка-финальной-модели-на-тестовой-выборке" data-toc-modified-id="Проверка-финальной-модели-на-тестовой-выборке-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Проверка финальной модели на тестовой выборке</a></span></li><li><span><a href="#Проверка-модели-на-адекватность" data-toc-modified-id="Проверка-модели-на-адекватность-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Проверка модели на адекватность</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Выводы</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# Очистка золота происходит в три этапа:
# * флотация
# * первый этап очистки
# * второй этап очистки
#
# на каждом этапе данные, которые описывают технологический процесс разделены на 4 группы:
# * входные параметры
# * выходные параметры
# * параметры очистной устанвки
# * расчетные величины

# %% [markdown]
# Метрикой качества данного производства служит sMATE

# %% [markdown]
# ![Image.png](attachment:Image.png)

# %% [markdown]
# Итоговой метрикой будет

# %% [markdown]
# ![Image%20%282%29.png](attachment:Image%20%282%29.png)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Вижу твое добавленное описание проекта. Молодец! Это поможет тебе расставлять акценты в выводах.

# %% [markdown]
# Для каждого этапа необходимо обучить отдельную модель

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.pipeline import  make_pipeline
from sklearn.impute import KNNImputer
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import make_scorer, mean_absolute_error
from sklearn.dummy import DummyRegressor

from scipy import stats as st

from sklearn.metrics import mean_absolute_error

# %%
data_train = pd.read_csv('/datasets/gold_recovery_train_new.csv')
data_test = pd.read_csv('/datasets/gold_recovery_test_new.csv')
data_full = pd.read_csv('/datasets/gold_recovery_full_new.csv')

# %%
data_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19438 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19438 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
# ...

# %%
data_train.describe().T
# Out:
#                                               count        mean        std  \
# final.output.concentrate_ag                 14148.0    5.142034   1.369586
# final.output.concentrate_pb                 14148.0   10.132960   1.654930
# final.output.concentrate_sol                13938.0    9.202849   2.790516
# final.output.concentrate_au                 14149.0   44.003792   4.905261
# final.output.recovery                       14149.0   66.518832  10.295402
# ...                                             ...         ...        ...
# secondary_cleaner.state.floatbank5_a_level  14148.0 -483.956022  37.892788
# secondary_cleaner.state.floatbank5_b_air    14148.0   13.064590   5.765617
# secondary_cleaner.state.floatbank5_b_level  14148.0 -483.966564  39.207913
# secondary_cleaner.state.floatbank6_a_air    14147.0   19.577539   5.764417
# secondary_cleaner.state.floatbank6_a_level  14148.0 -506.798480  37.079249
#
# ...

# %%
data_test.describe().T
# Out:
#                                              count         mean         std  \
# primary_cleaner.input.sulfate               5286.0   174.839652   43.027080
# primary_cleaner.input.depressant            5285.0     8.683596    3.072050
# primary_cleaner.input.feed_size             5290.0     7.266339    0.610219
# primary_cleaner.input.xanthate              5286.0     1.383803    0.643474
# primary_cleaner.state.floatbank8_a_air      5290.0  1539.494325  116.797884
# primary_cleaner.state.floatbank8_a_level    5290.0  -497.665883   19.952431
# primary_cleaner.state.floatbank8_b_air      5290.0  1545.174232  122.224588
# primary_cleaner.state.floatbank8_b_level    5290.0  -500.273098   32.968307
# primary_cleaner.state.floatbank8_c_air      5290.0  1527.272362  122.538034
# primary_cleaner.state.floatbank8_c_level    5290.0  -498.330680   21.964876
# primary_cleaner.state.floatbank8_d_air      5290.0  1544.844335  124.773081
# ...

# %%
data_full.describe().T
# Out:
#                                               count        mean        std  \
# final.output.concentrate_ag                 19438.0    5.168470   1.372348
# final.output.concentrate_pb                 19438.0    9.978895   1.669240
# final.output.concentrate_sol                19228.0    9.501224   2.787537
# final.output.concentrate_au                 19439.0   44.076513   5.129784
# final.output.recovery                       19439.0   67.050208  10.125840
# ...                                             ...         ...        ...
# secondary_cleaner.state.floatbank5_a_level  19438.0 -488.684065  34.533396
# secondary_cleaner.state.floatbank5_b_air    19438.0   12.198224   5.333024
# secondary_cleaner.state.floatbank5_b_level  19438.0 -487.149827  38.347312
# secondary_cleaner.state.floatbank6_a_air    19437.0   18.959024   5.550498
# secondary_cleaner.state.floatbank6_a_level  19438.0 -505.436305  37.689057
#
# ...

# %% [markdown]
# Проверим данные на полные дубликаты

# %%
data_train.duplicated().value_counts()
# Out:
# False    14149
# dtype: int64

# %%
data_test.duplicated().value_counts()
# Out:
# False    5290
# dtype: int64

# %%
data_full.duplicated().value_counts()
# Out:
# False    19439
# dtype: int64

# %% [markdown]
# Проверим количесво пропусков в таблицах

# %%
data_train.isna().sum().sort_values(ascending=False)
# Out:
# secondary_cleaner.output.tail_sol           1605
# rougher.state.floatbank10_e_air              436
# rougher.input.floatbank11_xanthate           428
# primary_cleaner.output.concentrate_sol       286
# secondary_cleaner.state.floatbank2_a_air     217
#                                             ...
# rougher.output.concentrate_pb                  0
# rougher.output.concentrate_au                  0
# rougher.output.recovery                        0
# rougher.output.tail_pb                         0
# date                                           0
# Length: 87, dtype: int64

# %%
data_test.isna().sum().sort_values(ascending=False)
# Out:
# rougher.input.floatbank11_xanthate            25
# rougher.input.feed_sol                        21
# secondary_cleaner.state.floatbank3_a_air       9
# rougher.input.floatbank11_sulfate              8
# primary_cleaner.input.depressant               5
# rougher.input.floatbank10_sulfate              5
# primary_cleaner.input.xanthate                 4
# primary_cleaner.input.sulfate                  4
# rougher.input.feed_rate                        3
# secondary_cleaner.state.floatbank2_a_air       3
# secondary_cleaner.state.floatbank2_b_air       2
# rougher.input.feed_size                        1
# secondary_cleaner.state.floatbank2_b_level     0
# rougher.state.floatbank10_f_level              0
# rougher.state.floatbank10_f_air                0
# secondary_cleaner.state.floatbank3_a_level     0
# secondary_cleaner.state.floatbank2_a_level     0
# date                                           0
# rougher.state.floatbank10_e_air                0
# ...

# %%
data_full.isna().sum().sort_values(ascending=False)
# Out:
# secondary_cleaner.output.tail_sol           1748
# rougher.input.floatbank11_xanthate           453
# rougher.state.floatbank10_e_air              436
# primary_cleaner.output.concentrate_sol       370
# secondary_cleaner.state.floatbank2_a_air     220
#                                             ...
# rougher.state.floatbank10_d_level              0
# rougher.state.floatbank10_d_air                0
# rougher.output.tail_pb                         0
# rougher.output.tail_sol                        0
# date                                           0
# Length: 87, dtype: int64

# %% [markdown]
# ### Корректировка типов данных

# %% [markdown]
# Стоит перевести столбец ```date``` в тип данных ```DateTime```

# %%
data_train['date'] = pd.to_datetime(data_train['date'], format='%Y-%m-%d %H:%M:%S')
data_train.set_index('date', inplace=True)

# %%
data_test['date'] = pd.to_datetime(data_test['date'], format='%Y-%m-%d %H:%M:%S')
data_test.set_index('date', inplace=True)

# %%
data_full['date'] = pd.to_datetime(data_full['date'], format='%Y-%m-%d %H:%M:%S')
data_full.set_index('date', inplace=True)

# %% [markdown]
# ### Заполнение пропусков

# %% [markdown]
# Пропуски заполним методом интерполяции введу того, что процесс очистки непрерывный, и соответственно значения не должны резко меняться.

# %%
for col in data_train.columns:
    data_train[col] = data_train[col].interpolate(axis='index', method='time')
    
for col in data_test.columns:
    data_test[col] = data_test[col].interpolate(axis='index', method='time')
    
for col in data_full.columns:
    data_full[col] = data_full[col].interpolate(axis='index', method='time')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Верно!👍:\
# </b> Верное решение по обработке пропусков, в признаках их не много. Все наблюдения представляют собой последовательные измерения, заполнить пропуски можно методами `pandas`: `ffill`/ `bfill`/ `interpolate` , это вполне уместно.\
# Хочу посоветовать тебе статью, которая рассматривает разные способы обработки пропусков, выделяет их плюсы и минусы, думаю, тебе может быть интересно: https://loginom.ru/blog/missing

# %% [markdown]
# Проверим на дубликаты

# %%
data_train.isna().sum().sort_values(ascending=False)
# Out:
# final.output.concentrate_ag                   0
# rougher.state.floatbank10_b_air               0
# rougher.state.floatbank10_f_air               0
# rougher.state.floatbank10_e_level             0
# rougher.state.floatbank10_e_air               0
#                                              ..
# primary_cleaner.state.floatbank8_d_air        0
# primary_cleaner.state.floatbank8_c_level      0
# primary_cleaner.state.floatbank8_c_air        0
# primary_cleaner.state.floatbank8_b_level      0
# secondary_cleaner.state.floatbank6_a_level    0
# Length: 86, dtype: int64

# %%
data_test.isna().sum().sort_values(ascending=False)
# Out:
# primary_cleaner.input.sulfate                 0
# primary_cleaner.input.depressant              0
# rougher.state.floatbank10_d_air               0
# rougher.state.floatbank10_d_level             0
# rougher.state.floatbank10_e_air               0
# rougher.state.floatbank10_e_level             0
# rougher.state.floatbank10_f_air               0
# rougher.state.floatbank10_f_level             0
# secondary_cleaner.state.floatbank2_a_air      0
# secondary_cleaner.state.floatbank2_a_level    0
# secondary_cleaner.state.floatbank2_b_air      0
# secondary_cleaner.state.floatbank2_b_level    0
# secondary_cleaner.state.floatbank3_a_air      0
# secondary_cleaner.state.floatbank3_a_level    0
# secondary_cleaner.state.floatbank3_b_air      0
# secondary_cleaner.state.floatbank3_b_level    0
# secondary_cleaner.state.floatbank4_a_air      0
# secondary_cleaner.state.floatbank4_a_level    0
# secondary_cleaner.state.floatbank4_b_air      0
# secondary_cleaner.state.floatbank4_b_level    0
# ...

# %%
data_full.isna().sum().sort_values(ascending=False)
# Out:
# final.output.concentrate_ag                   0
# rougher.state.floatbank10_b_air               0
# rougher.state.floatbank10_f_air               0
# rougher.state.floatbank10_e_level             0
# rougher.state.floatbank10_e_air               0
#                                              ..
# primary_cleaner.state.floatbank8_d_air        0
# primary_cleaner.state.floatbank8_c_level      0
# primary_cleaner.state.floatbank8_c_air        0
# primary_cleaner.state.floatbank8_b_level      0
# secondary_cleaner.state.floatbank6_a_level    0
# Length: 86, dtype: int64

# %% [markdown]
# ### Проверка правильности расчета коэффициента восстановления ```recovery```

# %% [markdown]
# Расчет **MAE** признаков ```rougher.output.recovery```

# %%
def recovery(c, f, t):
    return (c*(f-t))/((f)*(c-t)) * 100

# %%
rougher_recovery_calc = recovery(data_full['rougher.output.concentrate_au'], 
                                               data_full['rougher.input.feed_au'], 
                                               data_full['rougher.output.tail_au']
                                              )

display(mean_absolute_error(data_full['rougher.output.recovery'], rougher_recovery_calc))
# Out:
# 9.874045668302637e-15

# %% [markdown]
# Расчет **MAE** признаков ```final.output.recovery```

# %%
final_recovery_calc = recovery(data_full['final.output.concentrate_au'], 
                                               data_full['rougher.input.feed_au'], 
                                               data_full['final.output.tail_au']
                                              )

# %%
display(mean_absolute_error(data_full['final.output.recovery'], final_recovery_calc))
# Out:
# 8.595701443696112e-15

# %% [markdown]
# Значения метрики **MAE** крайне малы, что подтверждает правильность расчета коэффициента восстановления золота.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Твое расссчитанное значение `MAE` верно)

# %% [markdown]
# ### Анализ признаков в тренировочной и тестовой таблицах

# %% [markdown]
# Видно что таблица data_full есть исходная выборка для тренировочной и проверочной выборки. Необходимо удалить признаки из тренировочной выборки, которые отсутствуют в тестовой. Таргеты надо перенести из исходной таблицы.

# %% [markdown]
# проверим количество признаков в таблицах

# %%
data_train.shape
# Out:
# (14149, 86)

# %%
data_test.shape
# Out:
# (5290, 52)

# %%
data_full.shape
# Out:
# (19439, 86)

# %%
columns = []
for col in data_full.columns:
    if col not in data_test.columns:
        columns.append(col)
        
print(columns)
# Out:
# ['final.output.concentrate_ag', 'final.output.concentrate_pb', 'final.output.concentrate_sol', 'final.output.concentrate_au', 'final.output.recovery', 'final.output.tail_ag', 'final.output.tail_pb', 'final.output.tail_sol', 'final.output.tail_au', 'primary_cleaner.output.concentrate_ag', 'primary_cleaner.output.concentrate_pb', 'primary_cleaner.output.concentrate_sol', 'primary_cleaner.output.concentrate_au', 'primary_cleaner.output.tail_ag', 'primary_cleaner.output.tail_pb', 'primary_cleaner.output.tail_sol', 'primary_cleaner.output.tail_au', 'rougher.calculation.sulfate_to_au_concentrate', 'rougher.calculation.floatbank10_sulfate_to_au_feed', 'rougher.calculation.floatbank11_sulfate_to_au_feed', 'rougher.calculation.au_pb_ratio', 'rougher.output.concentrate_ag', 'rougher.output.concentrate_pb', 'rougher.output.concentrate_sol', 'rougher.output.concentrate_au', 'rougher.output.recovery', 'rougher.output.tail_ag', 'rougher.output.tail_pb', 'rougher.output.tail_sol', 'rougher.output.t
# ...

# %% [markdown]
# Признаки, которые отсутствуют в тестовой выборке, относятся к этапу ```output``` и ```calculation```. Логично, ведь задача предсказать коэффициент восстановления золота и этих параметров невозможно получить во время выполнения технологического процесса, поэтому их стоит исключить из тренировочной выборки.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# В тестовой выборке недоступны некоторые расчетные (calculation) и выходные (output) характеристики процесса, ведь их невозможно получить либо замерить во время выполнения технологического процесса.

# %%
data_train = data_train.drop(columns, axis=1)

# %% [markdown]
# Однако для обучения нам понадобяться данные таргетов из исходной таблицы.

# %%
data_train = data_train.join(data_full[['final.output.recovery', 'rougher.output.recovery']])
data_test = data_test.join(data_full[['final.output.recovery', 'rougher.output.recovery']])

# %% [markdown]
# ### Выводы

# %% [markdown]
# Проведена подготовка данных - преобразованны типы данных, заполнены пропуски, а также согласованны признаки в тренировочной и тестовой выборках.
#
# Также проведена проверка правильности расчета коэффициента восстановления золота.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Вытягивание целевых признаков в тестовую выборку правильное) Привязка к дате - верное решение

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Расчет конццентрации металлов на разных этапах

# %% [markdown]
# Функция для получения списка признаков каждого этапа

# %%
d = {'Aurum' : [data_full['rougher.input.feed_au'].mean(),
             data_full['rougher.output.concentrate_au'].mean(),
             data_full['primary_cleaner.output.concentrate_au'].mean(),
             data_full['final.output.concentrate_au'].mean()
            ],
     'Argentum' : [data_full['rougher.input.feed_ag'].mean(),
             data_full['rougher.output.concentrate_ag'].mean(),
             data_full['primary_cleaner.output.concentrate_ag'].mean(),
             data_full['final.output.concentrate_ag'].mean()
            ],
     'Plumbum' : [data_full['rougher.input.feed_pb'].mean(),
             data_full['rougher.output.concentrate_pb'].mean(),
             data_full['primary_cleaner.output.concentrate_pb'].mean(),
             data_full['final.output.concentrate_pb'].mean()
            ]    
}

mean_values = pd.DataFrame(data=d, index=['Before Rougher Stage', 
                                          'After Rougher Stage',
                                          'After Primary Cleaner Stage',
                                          'After Secondary Cleaner Stage'
                                         ])

mean_values.plot(kind='line', figsize = (20, 5), title='Распределение концентраций металлов в процессе восстановления золотой руды')
# Out:
# <AxesSubplot:title={'center':'Распределение концентраций металлов в процессе восстановления золотой руды'}>

# %%
display(mean_values)
# Out:
#                                    Aurum   Argentum   Plumbum
# Before Rougher Stage            8.266097   8.794927  3.585469
# After Rougher Stage            19.772000  11.994759  7.606272
# After Primary Cleaner Stage    32.119400   8.442408  9.810091
# After Secondary Cleaner Stage  44.076513   5.168385  9.978819

# %% [markdown]
# Из данного граффика видно что концентрация золота увеличивается в процессе восстановления от стадии к стадии вдвое, кроме последнией стадии очистки.
#
# Серебро увеличивает свое концентрацию после флотации, однако после двух стадий очистки концентрация падает, серебро уходит в "хвосты".
#
# Свинец увеличивает свою концентрацию после флотации и после первой очистки, после второй очистки его концентрация почти не меняется.
#
# Отличие процесса изменения концентрации серебра можно от золота и свинца объясняется химическим процессом очистки, серебро находиться в 5 периоде химической таблицы, в то время как золото и свинец в 6 периоде.
#
# Замедление восстановления свинца по сравнению с золотом связано с тем что свинец находиться в 4 группе, а золото в 1 и соответственно проявляет меньше металлических свойств.

# %% [markdown]
#  <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# - Мне интересно было изучить твои графики, практичный и красочный графический анализ. Напиши вывод о том, как изменяется содержание золота и других элементов в хронологическом порядке стадий очистки.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# ### Анализ отличий в размерах гранул руды для тренировочной и тестовой выборках

# %%
for df, name in zip([data_train, data_test],
                    ['Train', 'Test']):
    subset = df['rougher.input.feed_size']
    subset.plot(kind='kde', legend=True, xlim=(-10, 120), label=name)

# %%
alpha = 0.05

results = st.ttest_ind(data_train['rougher.input.feed_size'], data_test['rougher.input.feed_size'])

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу') 
    
print('Средний размер гранул руды в тренировочной выборке - {:.2f}'.format(data_train['rougher.input.feed_size'].mean()))
print('Средний размер гранул руды в тестовой выборке - {:.2f}'.format(data_test['rougher.input.feed_size'].mean()))
# Out:
# p-значение: 2.369589654487395e-30
# Отвергаем нулевую гипотезу
# Средний размер гранул руды в тренировочной выборке - 60.03
# Средний размер гранул руды в тестовой выборке - 55.95

# %% [markdown]
# Средние значение размера гранул в тестовой выборке отличается от значения в тренировочной. Статистический тест говорит о том, что мы можем считать партии золота в выборках разными. Но для обучения модели распределения даного параметра в наших выборках отличаются не столь сильно и если этот параметр не сильно коррелирует с коэффициентом восстановления золота, результаты будут корректными.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Красивая визуализация нормализованных распределений. Тут сложно не согласиться с твоими выводами. На самом деле в этом шаге ожидалось сравнить эти распределения на глаз (мы сравниваем чисто визуально, без проверки статистик), в этом случае наши распределения примерно похожи, и мы сможем правильно оценить модель.

# %% [markdown]
# ### Расчёт финальных концентраций

# %%
d = {'Before Rougher' : data_full['rougher.input.feed_au'] + 
                        data_full['rougher.input.feed_ag'] + 
                        data_full['rougher.input.feed_pb'] +
                        data_full['rougher.input.feed_sol'],
     'After Rougher' : data_full['rougher.output.concentrate_au'] + 
                       data_full['rougher.output.concentrate_ag'] + 
                       data_full['rougher.output.concentrate_pb'] +
                       data_full['rougher.output.concentrate_sol'],
     'After Primary Cleaner' : data_full['primary_cleaner.output.concentrate_au'] + 
                               data_full['primary_cleaner.output.concentrate_ag'] + 
                               data_full['primary_cleaner.output.concentrate_pb'] +
                               data_full['primary_cleaner.output.concentrate_sol'],
     'After Secondary Cleaner' : data_full['final.output.concentrate_au'] + 
                                 data_full['final.output.concentrate_ag'] + 
                                 data_full['final.output.concentrate_pb'] +
                                 data_full['final.output.concentrate_sol'],
}

mean_values = pd.DataFrame(data=d)

for col in mean_values.columns:
    mean_values[col].plot(kind='kde', legend=True, xlim=(0, 100), label=col, figsize=(20, 5))

# %%
data_full[data_full['rougher.input.feed_au'] < 0.1]['rougher.input.feed_au'].count()

index = mean_values[(mean_values['Before Rougher'] < 0.1) |
                    (mean_values['After Rougher'] < 0.1) |
                    (mean_values['After Primary Cleaner'] < 0.1) |
                    (mean_values['After Secondary Cleaner'] < 0.1)
                   ].index

data_full = data_full.drop(index = index, axis = 0)

# %% [markdown]
# ### Удаление выбросов в данных

# %%
d = {'Before Rougher' : data_full['rougher.input.feed_au'] + 
                        data_full['rougher.input.feed_ag'] + 
                        data_full['rougher.input.feed_pb'] +
                        data_full['rougher.input.feed_sol'],
     'After Rougher' : data_full['rougher.output.concentrate_au'] + 
                       data_full['rougher.output.concentrate_ag'] + 
                       data_full['rougher.output.concentrate_pb'] +
                       data_full['rougher.output.concentrate_sol'],
     'After Primary Cleaner' : data_full['primary_cleaner.output.concentrate_au'] + 
                               data_full['primary_cleaner.output.concentrate_ag'] + 
                               data_full['primary_cleaner.output.concentrate_pb'] +
                               data_full['primary_cleaner.output.concentrate_sol'],
     'After Secondary Cleaner' : data_full['final.output.concentrate_au'] + 
                                 data_full['final.output.concentrate_ag'] + 
                                 data_full['final.output.concentrate_pb'] +
                                 data_full['final.output.concentrate_sol'],
}

mean_values = pd.DataFrame(data=d)

for col in mean_values.columns:
    mean_values[col].plot(kind='kde', legend=True, xlim=(20, 100), label=col, figsize=(20, 5))

# %%
data_train = data_train.drop(index = index, axis = 0, errors = 'ignore')
data_test = data_test.drop(index = index, axis = 0, errors = 'ignore')

# %%
data_train.shape
# Out:
# (13602, 54)

# %%
stage = []
parameter = []

for col in data_full.columns:
    col_list = col.split(sep='.')

    if col_list[0] not in stage:
        stage.append(col_list[0])
        
    if col_list[1] not in parameter:
        parameter.append(col_list[1])
        
print(stage)
print(parameter)
# Out:
# ['final', 'primary_cleaner', 'rougher', 'secondary_cleaner']
# ['output', 'input', 'state', 'calculation']

# %%
def filter_columns(stage, parameter):
    ind = []
    for col in data_train.columns:
        col_list = col.split(sep='.')
        if col_list[0] == stage and col_list[1] == parameter and col_list[2] not in ind:
            ind.append(stage + '.' + parameter + '.' + col_list[2] )
            
    return ind

# %%
def filter_columns_1(stage):
    ind = []
    for col in data_train.columns:
        col_list = col.split(sep='.')
        if col_list[0] == stage:
            ind.append(stage + '.' + col_list[1] + '.' + col_list[2] )
            
    return ind

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Замечательно, суммарную концентрацию всех веществ на разных стадиях исследовали и нашли аномалии.
#
# Ведь отдельно по каждому веществу они могут быть (не всегда же есть крупицы золота в руде), а вот суммарно - вряд ли (в руде хоть какие-то элементы, но будут). А если мы имеем ноль, значит большая вероятность неточности в измерениях.
#
# Обучающую выборку нужно очистить от таких аномалий

# %% [markdown]
# ### Изучиние корреляции данных по каждому этапу

# %%
correliations = []
for index in range(4):
    for col in filter_columns_1(stage[index]):
            a = [col, data_train['rougher.output.recovery'].corr(data_train[col])]
            correliations.append(a)

from operator import itemgetter 
for i in sorted(correliations, key=itemgetter(1)): 
    print(i)
# Out:
# ['rougher.state.floatbank10_c_air', -0.34089434436257754]
# ['rougher.state.floatbank10_d_air', -0.338636126825856]
# ['rougher.state.floatbank10_b_air', -0.2894334304551483]
# ['rougher.state.floatbank10_e_air', -0.23130901675216378]
# ['rougher.state.floatbank10_d_level', -0.19275631026736673]
# ['rougher.state.floatbank10_b_level', -0.1917933679891595]
# ['rougher.state.floatbank10_c_level', -0.19114300562078756]
# ['rougher.state.floatbank10_f_level', -0.1901087524647655]
# ['rougher.state.floatbank10_e_level', -0.18905771843412952]
# ['rougher.state.floatbank10_f_air', -0.18069893504424378]
# ['secondary_cleaner.state.floatbank6_a_air', -0.12367238783457853]
# ['secondary_cleaner.state.floatbank3_b_level', -0.11520037814954351]
# ['secondary_cleaner.state.floatbank6_a_level', -0.08309270185193564]
# ['secondary_cleaner.state.floatbank2_b_level', -0.08240637494147163]
# ['secondary_cleaner.state.floatbank2_a_level', -0.0743105178552924]
# ...

# %%
correliations = []
for index in range(4):
    for col in filter_columns_1(stage[index]):
            a = [col, data_train['final.output.recovery'].corr(data_train[col])]
            correliations.append(a)

from operator import itemgetter 
for i in sorted(correliations, key=itemgetter(1)): 
    print(i)
# Out:
# ['rougher.state.floatbank10_c_air', -0.19730586985828832]
# ['rougher.state.floatbank10_d_air', -0.18904216438758945]
# ['rougher.state.floatbank10_b_air', -0.15645055372094832]
# ['rougher.state.floatbank10_e_air', -0.13014335676648997]
# ['secondary_cleaner.state.floatbank4_b_level', -0.10907022317856496]
# ['rougher.state.floatbank10_f_air', -0.09840734254856354]
# ['rougher.state.floatbank10_e_level', -0.0975984997692604]
# ['rougher.state.floatbank10_c_level', -0.09648453010821191]
# ['rougher.state.floatbank10_d_level', -0.09596767655719578]
# ['rougher.state.floatbank10_f_level', -0.09553144018935701]
# ['rougher.state.floatbank10_b_level', -0.0860209935620956]
# ['secondary_cleaner.state.floatbank6_a_level', -0.051597211747119745]
# ['primary_cleaner.state.floatbank8_d_level', -0.03790492685252842]
# ['rougher.input.floatbank10_sulfate', -0.020658727651213172]
# ['secondary_cleaner.state.floatbank2_b_level', -0.018902455238269927]
# ...

# %% [markdown]
# ### Выводы

# %% [markdown]
# Анализ демонстрирует, что размер гранул слабо коррелирует с коэффициентами восстановления золота на разных стадиях, и не смотря на то, что теория о равенстве средних двух выборок была отвергнута, на финальные результаты это не должно повлиять, ввиду слабой корреляции параметров.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Твой анализ данных интересно было изучить. Приступаем к построению моделей)

# %% [markdown]
# ## Модель

# %% [markdown]
# ### Функция для расчета финальной метрики sMAPE

# %%
def smape(y_true,y_pred):
    return np.mean(abs(y_true - y_pred) / ((abs(y_true) + abs(y_pred)) / 2)) * 100

# %%
def final_smape(r, f):
    return (0.25*r + 0.75*f)

# %%
custom_score = make_scorer(smape, greater_is_better=False)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Функция правильная) Молодец, что для избежания дублирования кода вначале используешь функцию для невзвешенной sMAPE.

# %% [markdown]
# ### Обучение моделей

# %% [markdown]
# Разделение выборок на фичи и таргеты

# %%
features_rougher_train = data_train.drop(['rougher.output.recovery', 'final.output.recovery'], axis = 1)
target_rougher_train = data_train['rougher.output.recovery']

features_final_train = data_train.drop(['rougher.output.recovery', 'final.output.recovery'], axis = 1)
target_final_train = data_train['final.output.recovery']

features_rougher_test = data_test.drop(['rougher.output.recovery', 'final.output.recovery'], axis = 1)
target_rougher_test = data_test['rougher.output.recovery']

features_final_test = data_test.drop(['rougher.output.recovery', 'final.output.recovery'], axis = 1)
target_final_test = data_test['final.output.recovery']

# %% [markdown]
# Инициализация ```pipeline``` для масштабирования данных и дальнейшего обучения моделей

# %%
model_rf = make_pipeline(StandardScaler(), RandomForestRegressor())
model_dt = make_pipeline(StandardScaler(), DecisionTreeRegressor())
model_lr = make_pipeline(StandardScaler(), LinearRegression())

# %% [markdown]
# Пределы гиперпараметров для поиска наилучших

# %%
parameters_rf = {'randomforestregressor__n_estimators':[5,100],
                 'randomforestregressor__max_depth':[1,10]}
parameters_dt = {'decisiontreeregressor__max_depth':[1,10]}

# %% [markdown]
# Поиск наилучших гиперпараметров и проверка их с помощью кроссвалидации

# %%
grid_rougher_dt = GridSearchCV(model_dt, param_grid = parameters_dt, scoring = custom_score)
grid_final_dt = GridSearchCV(model_dt, param_grid = parameters_dt, scoring = custom_score)

# %%
grid_rougher_rf = GridSearchCV(model_rf, param_grid = parameters_rf, scoring = custom_score)
grid_final_rf = GridSearchCV(model_rf, param_grid = parameters_rf, scoring = custom_score)

# %% [markdown]
# Обучение алгоритма ```Decision Tree Regressor```

# %%
grid_rougher_dt.fit(features_rougher_train, target_rougher_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('decisiontreeregressor',
#                                         DecisionTreeRegressor())]),
#              param_grid={'decisiontreeregressor__max_depth': [1, 10]},
#              scoring=make_scorer(smape, greater_is_better=False))

# %%
grid_final_dt.fit(features_final_train, target_final_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('decisiontreeregressor',
#                                         DecisionTreeRegressor())]),
#              param_grid={'decisiontreeregressor__max_depth': [1, 10]},
#              scoring=make_scorer(smape, greater_is_better=False))

# %%
grid_rougher_dt.best_params_
# Out:
# {'decisiontreeregressor__max_depth': 1}

# %%
grid_final_dt.best_params_
# Out:
# {'decisiontreeregressor__max_depth': 1}

# %% [markdown]
# Обучение алгоритма ```Random Forest Regressor```

# %%
grid_rougher_rf.fit(features_rougher_train, target_rougher_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('randomforestregressor',
#                                         RandomForestRegressor())]),
#              param_grid={'randomforestregressor__max_depth': [1, 10],
#                          'randomforestregressor__n_estimators': [5, 100]},
#              scoring=make_scorer(smape, greater_is_better=False))

# %%
grid_final_rf.fit(features_final_train, target_final_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('randomforestregressor',
#                                         RandomForestRegressor())]),
#              param_grid={'randomforestregressor__max_depth': [1, 10],
#                          'randomforestregressor__n_estimators': [5, 100]},
#              scoring=make_scorer(smape, greater_is_better=False))

# %%
grid_rougher_rf.best_params_
# Out:
# {'randomforestregressor__max_depth': 10,
#  'randomforestregressor__n_estimators': 100}

# %%
grid_final_rf.best_params_
# Out:
# {'randomforestregressor__max_depth': 10,
#  'randomforestregressor__n_estimators': 100}

# %% [markdown]
# Обучение алгоритма ```Linear Regression```

# %%
final_lr = cross_val_score(model_lr, features_final_train, target_final_train, scoring = custom_score, cv = 5).mean()
rougher_lr = cross_val_score(model_lr, features_rougher_train, target_rougher_train, scoring = custom_score, cv = 5).mean()

# %%
print('Результаты подбора лучшей модели')
print('Финальная метрика sMAPE для модели Decision Tree Regressor - {:.2f}'.format(final_smape(grid_rougher_dt.best_score_, grid_final_dt.best_score_)))
print('Финальная метрика sMAPE для модели Random Forest Regressor - {:.2f}'.format(final_smape(grid_rougher_rf.best_score_, grid_final_rf.best_score_)))
print('Финальная метрика sMAPE для модели Linear Regression - {:.2f}'.format(final_smape(rougher_lr, final_lr)))
# Out:
# Результаты подбора лучшей модели
# Финальная метрика sMAPE для модели Decision Tree Regressor - -9.10
# Финальная метрика sMAPE для модели Random Forest Regressor - -8.64
# Финальная метрика sMAPE для модели Linear Regression - -10.03

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Лучшую модель определили, хорошо)

# %% [markdown]
# ### Проверка финальной модели на тестовой выборке

# %%
rougher_predicted = grid_rougher_rf.predict(features_rougher_test)
final_predicted = grid_final_rf.predict(features_final_test)

# %%
result = final_smape(smape(target_rougher_test, rougher_predicted), smape(target_final_test, final_predicted))

# %%
print('Финальный sMAPE тестовой выборки = {:.2f}'.format(result))
# Out:
# Финальный sMAPE тестовой выборки = 7.12

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Тестирование лучшей модели проведено правильно

# %% [markdown]
# ### Проверка модели на адекватность

# %%
dummy_rougher = DummyRegressor(strategy="mean")
dummy_final = DummyRegressor(strategy="mean")

dummy_rougher.fit(features_rougher_train, target_rougher_train)
dummy_final.fit(features_final_train, target_final_train)

dummy_rourher_predicted = dummy_rougher.predict(features_rougher_test)
dummy_final_predicted = dummy_final.predict(features_final_test)

print('Финальный sMAPE тестовой выборки = {:.2f}'.format(final_smape(smape(target_rougher_test, dummy_rourher_predicted), 
                                                                     smape(target_final_test, dummy_final_predicted)
                                                                    )
                                                        )
     )
# Out:
# Финальный sMAPE тестовой выборки = 7.78

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что проводишь сравнение своей модели с константной дамми моделью. В каждом проекте при оценке качества модели, имеет смысл проводить такую проверку на адекватность.

# %% [markdown]
# ## Выводы

# %% [markdown]
# В данном проекте изучался процесс восстановдления золота. Целью проекта являлось построение модели предсказания коэффициента восстановления. Для этого:
# * Проведена подготовка данных, корректировка типов данных, заполнение пропусков методом интерполяции
# * Проведен исследовательский анализ данных процесса восстановления золота и золотой руды, в ходе которого были изучены:
#     * процессы изменения концентраций металлов в процессе восстановления
#     * средние значения размеров гранул руды для тренировочной и тестовой выборке
#     * процесс изменения общий концентрации продукта в процессе восстановления
# * Произведен поиск наиболее точной модели -
#     * модель ```Random Forest Regressor``` со следующими параметрами: ```max_depth``` = 10, ```n_estimators``` = 100
#     * финальное sMAPE модели - 8.64
# * Тестирование модели на тестовых данных подтвердило адекватность модели
#     * финальное sMAPE модели - 7.12
#     * проверка на адекватность модели "средним" дал финальное sMAPE модели - 7.78

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера <a class="tocSkip"> </h2>
#
#
# У меня сложилось хорошее общее впечатление о проекте, тебе удалось неплохо справиться с таким объемным и сложным проектом. Молодец! Подготовлены данные для анализа, изучен каждый параметр. Все красиво визуализировано, построено несколько моделей регрессии и оценено их качество. Осмысленная аналитика и дельная модельная работа - многое удалось как надо)
#
# Отмечу отдельные положительные моменты проекта🙂:
#
# - в ходе проекта встречались функции, помогающие избавиться от дублирования кода;
# - много красивых визуализаций в проекте и хорошая интерпретация;
# - при обучении моделей использована кросс-валидация и поиск гиперпараметров.
#
# Есть несколько моментов всего, на которые стоит ещё раз взглянуть, их я обзначил тебе в комментариях по ходу проекта. Предлагаю тебе доработать проект по моим комментариям, чтобы довести его до совершенства.
#
# Если будут вопросы, обращайся, с удовольствием на них отвечу.
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
#
#
# Теперь почти идеально. Принимаю работу)
#
# Если хочешь лучше разобраться в ML, то могу посоветовать тебе:
#
# - Открытый курс машинного обучения: https://habr.com/ru/company/ods/blog/322626/
#
# - Книжка от ШАД: https://academy.yandex.ru/handbook/ml/
#
# - Также рекомендую лекции от Andrew Ng: https://www.youtube.com/watch?v=PPLop4L2eGk&list=PLLssT5z_DsK-h9vYZkQkYNWcItqhlRJLN
# - Избежать утечки данных при кросс-валидации тебе поможет <a href="https://towardsdatascience.com/pipeline-columntransformer-and-featureunion-explained-f5491f815f">конвеерная обработка данных</a>.
#
# - Не все признаки приносят пользу при моделировании. Инструмент <a href="https://proglib.io/p/feature-selector">FeatureSelector</a> поможет тебе отобрать важные признаки и избавит от ручной обработки.  Также можешь посмотреть статью на <a href="https://www.kaggle.com/code/prashant111/comprehensive-guide-on-feature-selection/notebook">Kaggle</a> (она сложнее).
#
#
# В этом проекте были отработаны несколько моментов. А самый очевидный: заметно, что разность метрик качества (константной и нашей модели) -  не слишком большая. Такое расхождение метрик допустимо в этом проекте. Что тогда  для дальнейшего улучшения качества моделирования возможно тут пересмотреть?
# Попробую описать для тебя:
# 1. Качество данных на входе модели машинного обучения: повторно оценить аномалии, пропуски, соответствие законам химии и физики, все ли правдоподобно?
# 2. Работа с моделями машинного обучения:
# - Создание новых признаков для моделей, Features Engineering: возможно стоит обратиться к технологу производства и ещё раз пробежаться по бизнес-цепочке процесса.
# - Отбор самих моделей машинного обучения и гиперпараметров.
#
# 3. Параметры производственного процесса, к примеру: температура сырья, скорость ленточного конвейера, и.т.п.
#
#
# Если провести Анализ измерительных систем, или MSA, то можно разобраться в причинах неточности полученных с производства данных. Статистический анализ данных, или SPC, - тоже будет являться незаменимым помощником в решении нашей задачи.
#
# Добавлю здесь, что цель нашего проекта достигнута, а именно пройдены важные этапы подготовки данных и построения модели для производства золота.
#
# Успехов тебе в следующем спринте!
#
# Рад был помочь тебе)
#
# </div>

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке выполнения
# - [x]  Выполнен шаг 1: данные подготовлены
#     - [x]  Проверена формула вычисления эффективности обогащения
#     - [x]  Проанализированы признаки, недоступные в тестовой выборке
#     - [x]  Проведена предобработка данных
# - [x]  Выполнен шаг 2: данные проанализированы
#     - [x]  Исследовано изменение концентрации элементов на каждом этапе
#     - [x]  Проанализированы распределения размеров гранул на обучающей и тестовой выборках
#     - [x]  Исследованы суммарные концентрации
# - [x]  Выполнен шаг 3: построена модель прогнозирования
#     - [x]  Написана функция для вычисления итогового *sMAPE*
#     - [x]  Обучено и проверено несколько моделей
#     - [x]  Выбрана лучшая модель, её качество проверено на тестовой выборке
